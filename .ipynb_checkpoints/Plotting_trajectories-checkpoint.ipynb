# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pylab as plt
# %matplotlib inline  
from dypy.plotting import Mapfigure
from mpl_toolkits.basemap import Basemap

# %%
# initialize the variable for reading trajectories from an ascii file
from dypy.lagranto import Tra
trajs = Tra()

# %%
# load the trajectories
trajs.load_ascii('lagrantodata/wcb.1')
# list of variables for plotting
variables = ['p', 'Q', 'T', 'TH']
titles = ['Elevation, hPa', 'Specific humidity, g/kg', 'Temperature, K', 'Potential temperature, K']

for i in range(4):
    # set up the map and projection
    fig = plt.figure(figsize = (10,8))
    m = Mapfigure(width=7500000,height=6500000,
            resolution='l',projection='laea',\
            lat_ts=50,lat_0=52,lon_0=-10.)
    m.drawmap(nbrem=10, nbrep=10)    
    # plot the trajectories
    cont = m.plot_traj(trajs, variables[i], cmap = 'jet')
    # display the colorbar
    cb = fig.colorbar(cont)    
    # set font size in captions
    for font_objects in cb.ax.yaxis.get_ticklabels():
        font_objects.set_size(20)
    # set figure title
    plt.title(titles[i], fontsize=24)
    # save the figure
    figname = 'lagrantodata/' + variables[i] + '.png'
    fig.savefig(figname, bbox_inches='tight')
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
trajs #info about trajectories from the file
# Out:
#              148 trajectories with 9 time steps.
#              Available fields: time/lon/lat/p/T/Q/TH
#              total duration: 2880.0 minutes

# %%
trajs['p'][140,:] #this is how you access pressure along trajectory #11
# Out:
# masked_array(data=[790.0, 782.0, 767.0, 632.0, 525.0, 439.0, 330.0, 300.0,
#                    288.0],
#              mask=[False, False, False, False, False, False, False, False,
#                    False],
#        fill_value=1e+20)
